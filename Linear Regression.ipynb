# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.externals import joblib
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Only continuous features

# %%
train_numerical = pd.read_csv('../data/processed/train_numerical.csv')

# %%
LABEL = 'SalePrice'
FEATURES = list(train_numerical.columns)
FEATURES.remove(LABEL)

# %%
training_set, validation_set = train_test_split(train_numerical, test_size=0.33, random_state=42)
training_set.head()
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 1013    0.235294     0.000000  0.036598     0.333333     0.857143   0.681159
# 333     0.000000     0.191693  0.033186     0.000000     0.285714   0.565217
# 433     0.588235     0.169329  0.012255     0.500000     0.428571   0.971014
# 677     0.058824     0.159744  0.021968     0.166667     0.714286   0.355072
# 1074    0.000000     0.364217  0.042333     0.500000     0.428571   0.855072
#
#       YearRemodAdd  MasVnrArea  TotalBsmtSF  LowQualFinSF      ...        \
# 1013      0.833333      0.1575     0.249532           0.0      ...
# 333       0.000000      0.0000     0.224891           0.0      ...
# 433       0.950000      0.0450     0.392389           0.0      ...
# 677       0.000000      0.0000     0.192140           0.0      ...
# 1074      0.683333      0.0000     0.283843           0.0      ...
#
#       Fireplaces  GarageYrBlt  GarageCars  MiscVal    MoSold  YrSold  \
# ...

# %%
lr_numerical = LinearRegression()
lr_numerical.fit(training_set[FEATURES], training_set[LABEL])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predictions = lr_numerical.predict(validation_set[FEATURES])
print("Mean Squared Error", mean_squared_error(y_true=validation_set.SalePrice, y_pred=predictions))
# Out:
# Mean Squared Error 0.002765601998970589

# %% [markdown]
# ## For all possible features, continuous + categorical

# %%
train = pd.read_csv('../data/processed/train_all.csv')

# %%
LABEL = 'SalePrice'
FEATURES = list(train.columns)
FEATURES.remove(LABEL)

# %%
training_set, validation_set = train_test_split(train, test_size=0.33, random_state=42)
training_set.head()
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 1013    0.235294     0.000000  0.036598     0.333333     0.857143   0.681159
# 333     0.000000     0.191693  0.033186     0.000000     0.285714   0.565217
# 433     0.588235     0.169329  0.012255     0.500000     0.428571   0.971014
# 677     0.058824     0.159744  0.021968     0.166667     0.714286   0.355072
# 1074    0.000000     0.364217  0.042333     0.500000     0.428571   0.855072
#
#       YearRemodAdd  MasVnrArea  TotalBsmtSF  LowQualFinSF      ...        \
# 1013      0.833333      0.1575     0.249532           0.0      ...
# 333       0.000000      0.0000     0.224891           0.0      ...
# 433       0.950000      0.0450     0.392389           0.0      ...
# 677       0.000000      0.0000     0.192140           0.0      ...
# 1074      0.683333      0.0000     0.283843           0.0      ...
#
#       KitchenQual  Functional  FireplaceQu  GarageType  GarageFinish  \
# ...

# %%
lr = LinearRegression()
lr.fit(training_set[FEATURES], training_set[LABEL])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predictions = lr.predict(validation_set[FEATURES])
print("Mean Squared Error", mean_squared_error(y_true=validation_set.SalePrice, y_pred=predictions))
# Out:
# Mean Squared Error 0.0024230001266813553
